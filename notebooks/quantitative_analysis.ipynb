# %%
import pandas as pd
import numpy as np
import talib
import matplotlib.pyplot as plt

import os
import sys

# %%
rpath = os.path.abspath('..')
if rpath not in sys.path:
    sys.path.insert(0, rpath)

# %%
from scripts.analyze_stock_data import analyze_stock_data
analyze_stock_data('../Data/AAPL_historical_data.csv')
# Out:
# Annual Volatility: 0.4428139045746556

# %%
analyze_stock_data('../Data/AMZN_historical_data.csv')
# Out:
# Annual Volatility: 0.5624201280659038

# %%
analyze_stock_data('../Data/GOOG_historical_data.csv')
# Out:
# Annual Volatility: 0.3066668478935509

# %%
analyze_stock_data('../Data/META_historical_data.csv')
# Out:
# Annual Volatility: 0.385387407083589

# %%
analyze_stock_data('../Data/MSFT_historical_data.csv')
# Out:
# Annual Volatility: 0.3353677248890819

# %%
analyze_stock_data('../Data/NVDA_historical_data.csv')
# Out:
# Annual Volatility: 0.6010903147343263

# %%
analyze_stock_data('../Data/TSLA_historical_data.csv')
# Out:
# Annual Volatility: 0.5694405497796355
